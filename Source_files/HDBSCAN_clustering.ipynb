# %% [markdown]
# # Importing Necessary Libraries
# ##### This section imports the required libraries for generating data, running HDBSCAN Clustering, and visualizing the results.

# %%
import hdbscan
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

# %% [markdown]
# # Generating Synthetic Data
# ##### Here, we generate a synthetic dataset with three centers using `make_blobs`. This data will be used to demonstrate the HDBSCAN clustering algorithm.

# %%
# Generate sample data
X, _ = make_blobs(n_samples=300, centers=3, cluster_std=0.5, random_state=0)

# Plot the generated data
plt.figure(figsize=(8, 6))
plt.scatter(X[:, 0], X[:, 1], s=30)
plt.title("Generated Synthetic Data")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()

# %% [markdown]
# # Running HDBSCAN Clustering
# ##### In this section, we apply the HDBSCAN clustering algorithm to the synthetic data to identify clusters and noise points.

# %%
# Run HDBSCAN
hdb = hdbscan.HDBSCAN(min_cluster_size=10)
labels = hdb.fit_predict(X)

# %% [markdown]
# # Visualizing Clustering Results
# ##### This section visualizes the clustering results by plotting the data points with different colors for different clusters. Noise points will have a different color.

# %%
# Plot the clustered data
plt.figure(figsize=(8, 6))
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', s=30)
plt.title('HDBSCAN Clustering Results')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()
