# %% [markdown]
# # Importing Necessary Libraries
# ##### This section imports the required libraries for generating data, running Ward Clustering, and visualizing the results.

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

# %% [markdown]
# # Generating Synthetic Data
# ##### Here, we generate a synthetic dataset with three centers using `make_blobs`. This data will be used to demonstrate the Ward Clustering algorithm.

# %%
# Generate sample data
X, _ = make_blobs(n_samples=50, centers=3, cluster_std=0.5, random_state=0)

# Plot the generated data
plt.figure(figsize=(8, 6))
plt.scatter(X[:, 0], X[:, 1], s=50)
plt.title("Generated Synthetic Data")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()

# %% [markdown]
# # Running Ward Clustering
# ##### In this section, we apply the Ward Clustering algorithm using hierarchical methods to the synthetic data to create a dendrogram.

# %%
# Perform hierarchical clustering using Ward's method
Z = linkage(X, method='ward')

# %% [markdown]
# # Visualizing the Dendrogram
# ##### This section visualizes the results of the Ward Clustering algorithm using a dendrogram.

# %%
# Plot the dendrogram
plt.figure(figsize=(10, 7))
dendrogram(Z)
plt.title('Dendrogram for Ward Clustering')
plt.xlabel('Sample Index')
plt.ylabel('Distance')
plt.show()
